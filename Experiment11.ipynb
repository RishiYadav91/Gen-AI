# %% [markdown]
# <a href="https://colab.research.google.com/github/RishiYadav91/Gen-AI/blob/main/Experiment11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

from tensorflow.keras.models import Sequential from tensorflow.keras.layers import Dense from sklearn.preprocessing import MinMaxScaler

np.array([ X

[2, 5],

[4, 6],

[6, 7],

[8, 6],

[1, 4],

[7, 8],

[3, 5],

[9, 7]

y np.array([0, 0, 1, 1, 0, 1, 0, 1])

scaler = MinMaxScaler()

X_scaled = scaler.fit_transform(X)

model Sequential()

model.add(Dense(8, input_dim-2, activation 'relu'))

model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_scaled, y, epochs=100, verbose=1)

test_data = np.array([[5, 6]])

test scaled = scaler.transform(test_data)

prediction model.predict(test_scaled)

print("Prediction (0-Fail, 1-Pass):", prediction)
# Out:
#   File "/tmp/ipykernel_235/4127809590.py", line 3
#     from tensorflow.keras.models import Sequential from tensorflow.keras.layers import Dense from sklearn.preprocessing import MinMaxScaler
#                                                    ^
# SyntaxError: invalid syntax
